# %%
import pandas as pd

# %%
with open('../Data/11_randomizing_paintings.txt', 'r') as file:
    lines = file.read().strip().split('\n')

lines = lines[1:]

# %%
parsed = []
index = 0
for line in lines:
    parts = line.strip().split()
    painting_type = parts[0]
    num_tags = int(parts[1])
    tags = set(parts[2:]) 
    parsed.append({
        "index" : index,
        "Type": painting_type,
        "Num_Tags": num_tags,
        "Tags": tags
    })
    index += 1
df = pd.DataFrame(parsed)
df = df.sort_values(by='Type', ascending=False)


df_p = df[df['Type'] == 'P'].copy()
df_l = df[df['Type'] == 'L'].copy()
merged = []
for i in range(0, len(df_p), 2):
    if i + 1 < len(df_p):
        idx1, idx2 = df_p.iloc[i]['index'], df_p.iloc[i+1]['index']
        tags1, tags2 = df_p.iloc[i]['Tags'], df_p.iloc[i+1]['Tags']
        merged.append({
            "index": f"{idx1} {idx2}",
            "Type" : "P",
            "Tags": tags1.union(tags2)
        })

merged_df = pd.DataFrame(merged)

combined_df = pd.concat([merged_df, df_l], ignore_index=True)
combined_df = combined_df.sample(frac=1).reset_index(drop=True)
print(combined_df)

output = combined_df['index']  
len_output = len(output)

with open("../output/11_randomizing_paintings.txt", "w") as f:
    f.write(str(len_output) + "\n")
    for line in output.values:
        f.write(str(line)+'\n')
# Out:
#              index Type                                               Tags  \
# 0             6975    L  {wh5, wq3, w02, wq2, wj5, wk1, wx1, w42, w53, ...
# 1       2601 89125    P  {wq3, wh5, w34, wm, wp2, wh6, wl5, w6, w05, wr...
# 2            14116    L  {wb7, wn6, w31, w47, wj6, w01, wc4, wh4, wz2, ...
# 3            32696    L  {w85, wr5, w34, w6, wb5, w32, w01, wp6, wz4, w...
# 4            36452    L  {wq1, wn6, wd2, wc1, wm, wf, w01, wc4, wz4, w8...
# ...            ...  ...                                                ...
# 59995        13560    L  {wr2, wn6, wh5, w34, wm, wk3, wh6, w62, wk5, w...
# 59996        43545    L            {w57, ws2, wp2, wh4, wz4, wz6, wr5, w6}
# 59997        84884    L                          {ww6, wd1, w87, w52, wz6}
# 59998        76729    L                     {w85, wd2, w94, wp6, wl2, w82}
# 59999  37719 37783    P  {wq6, w34, wq2, wp2, w01, w87, wl5, wk5, w53, ...
#
#        Num_Tags
# 0          10.0
# 1           NaN
# 2          11.0
# 3          15.0
# 4          15.0
# ...         ...
# 59995      15.0
# 59996       8.0
# 59997       5.0
# 59998       6.0
# 59999       NaN
#
# [60000 rows x 4 columns]
