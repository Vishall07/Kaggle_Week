# %%
import pandas as pd

# %%
with open('../Data/110_oily_portraits.txt', 'r') as file:
    lines = file.read().strip().split('\n')
lines = lines[1:]

# %%
parsed = []
index = 0
for line in lines:
    parts = line.strip().split()
    painting_type = parts[0]
    num_tags = int(parts[1])
    tags = set(parts[2:]) 
    parsed.append({
        "index" : index,
        "Type": painting_type,
        "Num_Tags": num_tags,
        "Tags": tags
    })
    index += 1
df = pd.DataFrame(parsed)
df = df.sort_values(by='Type', ascending=False)


df_p = df[df['Type'] == 'P'].copy()
df_l = df[df['Type'] == 'L'].copy()
merged = []
for i in range(0, len(df_p), 2):
    if i + 1 < len(df_p):
        idx1, idx2 = df_p.iloc[i]['index'], df_p.iloc[i+1]['index']
        tags1, tags2 = df_p.iloc[i]['Tags'], df_p.iloc[i+1]['Tags']
        merged.append({
            "index": f"{idx1} {idx2}",
            "Type" : "P",
            "Tags": tags1.union(tags2)
        })

merged_df = pd.DataFrame(merged)

combined_df = pd.concat([merged_df, df_l], ignore_index=True)
combined_df = combined_df.sample(frac=1).reset_index(drop=True)
print(combined_df)

output = combined_df['index']  
len_output = len(output)

with open("../output/110_oily_portraits.txt", "w") as f:
    f.write(str(len_output) + "\n")
    for line in output.values:
        f.write(str(line)+'\n')
# Out:
#              index Type                                               Tags  \
# 0        2331 2330    P  {fk7, f3b, fmd, fmb, f17, fd8, fv1, fs5, f3g, ...
# 1        6678 6649    P  {fs8, f05, f8j, f3b, f72, fd6, fm8, f96, fqg, ...
# 2      21360 21359    P  {f65, ff1, f8b, f72, f7, fd, fdf, fgd, fmb, fj...
# 3      51051 51050    P  {f42, f7, f3d, fx, f83, fl7, fn7, fl9, fn3, f3...
# 4      33014 33013    P  {f65, f92, f8b, fk4, fq7, fcf, f1f, fr1, f7d, ...
# ...            ...  ...                                                ...
# 39995    6030 6029    P  {f22, f8c, ff1, fr8, f11, f4f, fwd, f3f, fl6, ...
# 39996  54597 54596    P  {f65, f4d, fdf, f61, f06, fxh, fl4, f85, fqg, ...
# 39997  69092 69091    P  {fk5, fsb, f95, fqb, fr6, fw9, ff5, ff3, fhg, ...
# 39998  15438 15437    P  {fmj, f65, f8c, ff1, fj, f93, fw7, fr1, fn6, f...
# 39999  21386 21387    P  {flj, f11, fk4, frg, fb2, fj6, fd8, fx, f1f, f...
#
#        Num_Tags
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 39995       NaN
# 39996       NaN
# 39997       NaN
# 39998       NaN
# 39999       NaN
#
# [40000 rows x 4 columns]
